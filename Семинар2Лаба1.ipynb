# %% [markdown]
# <a href="https://colab.research.google.com/github/mmanevskaya/pythonLabs/blob/main/%D0%A1%D0%B5%D0%BC%D0%B8%D0%BD%D0%B0%D1%802%D0%9B%D0%B0%D0%B1%D0%B01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# подключение библиотек
import pandas as pd
import random
import matplotlib.pyplot as plt
import math as math
# %matplotlib inline
import re

# %%
url = "https://raw.githubusercontent.com/nazgull08/ibm7/master/used_car_dataset.csv"
dataset = pd.read_csv(url)

# %% [markdown]
# Задание 1:
# Посмотреть данные датасеты

# %%
dataset
# Out:
#                                                car_name car_price_in_rupees  \
# 0     Hyundai Grand i10 Magna 1.2 Kappa VTVT [2017-2...         ₹ 4.45 Lakh
# 1                            Maruti Suzuki Alto 800 Lxi         ₹ 2.93 Lakh
# 2                               Tata Safari XZ Plus New        ₹ 22.49 Lakh
# 3                               Maruti Suzuki Ciaz ZXI+         ₹ 6.95 Lakh
# 4        Jeep Compass Sport Plus 1.4 Petrol [2019-2020]           ₹ 12 Lakh
# ...                                                 ...                 ...
# 2100                         Ford Figo Titanium1.5 TDCi          ₹ 3.6 Lakh
# 2101                    MINI Cooper Countryman Cooper D           ₹ 22 Lakh
# 2102                          Hyundai Verna 1.6 VTVT SX         ₹ 8.38 Lakh
# 2103                         Maruti Suzuki Ciaz VXi+ AT         ₹ 6.75 Lakh
# 2104                          Hyundai Verna 1.6 VTVT SX         ₹ 8.76 Lakh
#
# ...

# %% [markdown]
# Задание 2: Оставить автомобили с пробегом меньше 10000км

# %%
ds1 = dataset
# ds1["kms_driven"] = dataset["kms_driven"].map(lambda x: int(x[:-2].replace(",","")))
#ds1["car_price_in_rupees"] = dataset["car_price_in_rupees"].map(lambda x: int(x))
ds1
# Out:
#                                                car_name car_price_in_rupees  \
# 0     Hyundai Grand i10 Magna 1.2 Kappa VTVT [2017-2...         ₹ 4.45 Lakh
# 1                            Maruti Suzuki Alto 800 Lxi         ₹ 2.93 Lakh
# 2                               Tata Safari XZ Plus New        ₹ 22.49 Lakh
# 3                               Maruti Suzuki Ciaz ZXI+         ₹ 6.95 Lakh
# 4        Jeep Compass Sport Plus 1.4 Petrol [2019-2020]           ₹ 12 Lakh
# ...                                                 ...                 ...
# 2100                         Ford Figo Titanium1.5 TDCi          ₹ 3.6 Lakh
# 2101                    MINI Cooper Countryman Cooper D           ₹ 22 Lakh
# 2102                          Hyundai Verna 1.6 VTVT SX         ₹ 8.38 Lakh
# 2103                         Maruti Suzuki Ciaz VXi+ AT         ₹ 6.75 Lakh
# 2104                          Hyundai Verna 1.6 VTVT SX         ₹ 8.76 Lakh
#
# ...

# %% [markdown]
# Задание 3: Из оставшихся оставить автомобили не старше 2020 года

# %%
ds1 = ds1[ds1["year_of_manufacture"] > 2020]
ds1
# Out:
#                                             car_name car_price_in_rupees  \
# 2                            Tata Safari XZ Plus New        ₹ 22.49 Lakh
# 17                      Mercedes-Benz EQC 400 4MATIC           ₹ 95 Lakh
# 27                        Hyundai i20 Sportz 1.2 IVT          ₹ 8.9 Lakh
# 32                                Tata Nexon XZ Plus        ₹ 11.52 Lakh
# 35             Hyundai Santro Sportz CNG [2018-2020]         ₹ 5.93 Lakh
# ...                                              ...                 ...
# 2052                          BMW X1 sDrive20d xLine        ₹ 44.75 Lakh
# 2073                           Tata Nexon EV XZ Plus        ₹ 18.75 Lakh
# 2076                             Tata Safari XZA New        ₹ 26.15 Lakh
# 2084                  Renault Triber RXZ [2019-2020]         ₹ 7.65 Lakh
# 2097  Land Rover Discovery Sport SE R-Dynamic Petrol           ₹ 64 Lakh
#
#       kms_driven fuel_type       city  year_of_manufacture
# ...

# %% [markdown]
# Задание 4: создать список уникальных городов автомобилей

# %%
uniq_cities = ds1.drop_duplicates(subset=["city"])
#ds1["city"]
uniq_cities["city"]
# Out:
# 2         Bangalore
# 17             Pune
# 27        Ahmedabad
# 32            Delhi
# 232       Hyderabad
# 234          Mumbai
# 248         Chennai
# 271         Kolkata
# 308           Thane
# 422     Thiruvallur
# 577       Faridabad
# 735     Pallikarnai
# 1037          Noida
# 1416       Ambattur
# 1557    Poonamallee
# Name: city, dtype: object

# %%
ds1.groupby("year_of_manufacture").kms_driven.mean().plot()

# %%
ds1.groupby("year_of_manufacture").kms_driven.mean()
# Out:
# year_of_manufacture
# 2004    140000.000000
# 2005    140000.000000
# 2006     76000.000000
# 2007     96867.666667
# 2008     51316.166667
# 2009     99810.727273
# 2010     81232.900000
# 2011     71617.545455
# 2012     66745.454545
# 2013     64384.309278
# 2014     62355.489655
# 2015     58276.210784
# 2016     53078.442396
# 2017     49484.464646
# 2018     48493.050279
# 2019     49607.365462
# 2020     27723.611111
# 2021     17947.639053
# 2022      9926.854545
# Name: kms_driven, dtype: float64

# %%
ds1.groupby("city").kms_driven.mean().plot()
